# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv # This is a library that allows us to work with CSV files even if we're not using pandas

# %%
csvFile = open("/content/drive/My Drive/Colab Notebooks/BridgeUP_year1/Unit2_ClimateChange/sea_temp_anom_Sep_2011.csv", 'r') #'r' means we want to read
csvReader = csv.reader(csvFile, delimiter=',')
data_lists = list(csvReader)

# %%
height = len(data_lists)
width = len(data_lists[0])

print(width, height)
# Out:
# 720 360

# %%
grid = np.empty([height, width, 3], dtype=np.uint8)

# %%
all_values = [] # We will fill in this empty list with all the data values as we go

for r, row in enumerate(data_lists):
    for c, value in enumerate(row):
        if float(value) < 99998.0:
            all_values.append(float(value)) # This is where we fill in the list with all data values
        if float(value) <= -5:
            grid[r, c] = [255, 255, 255] # white
        elif float(value) <= -4.5:
            grid[r, c] = [0, 0, 0] # black
        elif float(value) <= -4.0:
            grid[r, c] = [80, 0, 100] # done
        elif float(value) <= -3.5:
            grid[r, c] = [87, 0, 150] # done
        elif float(value) <= -3.0:
            grid[r, c] = [68, 0, 204] # done
        elif float(value) <= -2.5:
            grid[r, c] = [25, 0, 255] # done
        elif float(value) <= -2.0:
            grid[r, c] = [0, 29, 255] # done
        elif float(value) <= -1.5:
            grid[r, c] = [0, 89, 255] # done
        elif float(value) <= -1.0:
            grid[r, c] = [0, 152, 255] # done
        elif float(value) <= -0.5:
            grid[r, c] = [0, 208, 255] # done
        elif float(value) <= 0:
            grid[r, c] = [242, 255, 0] # done
        elif float(value) <= 0.5:
            grid[r, c] = [255, 238, 0] # done
        elif float(value) <= 1.0:
            grid[r, c] = [255, 212, 0] # done
        elif float(value) <= 1.5:
            grid[r, c] = [255, 187, 0] # done
        elif float(value) <= 2.0:
            grid[r, c] = [255, 161, 0] # done
        elif float(value) <= 2.5:
            grid[r, c] = [255, 131, 0] # done
        elif float(value) <= 3.0:
            grid[r, c] = [255, 102, 0] # done
        elif float(value) <= 3.5:
            grid[r, c] = [255, 76, 0] # done
        elif float(value) <= 4.0:
            grid[r, c] = [255, 51, 0] # done
        elif float(value) <= 4.5:
            grid[r, c] = [255, 21, 0] # done
        # elif float(value) <= 5:
        #    grid[r, c] = [255, 21, 0] # done
        else:
            grid[r, c] = [0, 0, 0] # black -- the land

# %%
print(max(all_values)) # max of all values that are NOT 99999
print(min(all_values)) # min of all values that are NOT 99999
# Out:
# 5.0
# -5.0

# %%
plt.title("Sea Temperature Anomalies, Sep 2011")
plt.imshow(grid, cmap = "jet")
plt.clim(-5, 5)
plt.colorbar(orientation="horizontal",fraction=0.07,anchor=(1.0,0.0))
plt.axis('off')
plt.savefig("Land_temperature.png", dpi = 1000)
# plt.show()
plt.savefig("Sea_Temp_Anom_Sep_2011.png")
